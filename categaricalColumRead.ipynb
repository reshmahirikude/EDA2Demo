# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#importing the all ready exist excel file

# %%
path="Visadataset.csv"#path of file
pd.read_csv(path)#read the file
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#reading Columns
visa_df=pd.read_csv(path)#read the file
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_df.continent#contint column only display in series pattren
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent']#series of contient column
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']]#dataframe
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.columns#multiple columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols=['continent','education_of_employee']
visa_df[cols]
# Out:
#       continent education_of_employee
# 0          Asia           High School
# 1          Asia              Master's
# 2          Asia            Bachelor's
# 3          Asia            Bachelor's
# 4        Africa              Master's
# ...         ...                   ...
# 25475      Asia            Bachelor's
# 25476      Asia           High School
# 25477      Asia              Master's
# 25478      Asia              Master's
# 25479      Asia            Bachelor's
#
# [25480 rows x 2 columns]

# %%
visa_df#entire dataframe
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.values#entire sample list ,sample list of observation
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       dtype=object)

# %%
l1=[1,2,3]
l2=['A','B','C']
l=[l1,l2]
l
# Out:
# [[1, 2, 3], ['A', 'B', 'C']]

# %%
pd.DataFrame(l).values
# Out:
# array([[1, 2, 3],
#        ['A', 'B', 'C']], dtype=object)

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
col=['continent']
visa_df[col]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
#unique how many unique labels are there
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
l1=['A','A','B','C']
set(l1)
# Out:
# {'A', 'B', 'C'}

# %%
set(visa_df['continent'].values)
# Out:
# {'Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America'}

# %%
#nunique number of unique element
visa_df['continent'].nunique()#6 elements are reated in contient column
# Out:
# 6

# %%
con=visa_df['continent']=='Asia'
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#con=visa_df['continent']=='Asia'
len(visa_df['continent']=='Asia')
#visa_df[con]
# Out:
# 25480

# %%
con1=visa_df['continent']=='Africa'
visa_df[con1]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 4         EZYV05    Africa              Master's                  Y
# 18        EZYV19    Africa              Master's                  Y
# 74        EZYV75    Africa              Master's                  Y
# 194      EZYV195    Africa              Master's                  Y
# 242      EZYV243    Africa            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25385  EZYV25386    Africa             Doctorate                  Y
# 25408  EZYV25409    Africa              Master's                  Y
# 25443  EZYV25444    Africa            Bachelor's                  N
# 25446  EZYV25447    Africa              Master's                  N
# 25474  EZYV25475    Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 4                         N             1082         2005
# ...

# %%
len(visa_df[con])
# Out:
# 16861

# %%
unique_lable=visa_df['continent'].unique()
for i in unique_lable:
    con=visa_df['continent']==i
    print(i,":",len(visa_df[con]))
# Out:
# Asia : 16861
# Africa : 551
# North America : 3292
# Europe : 3732
# South America : 852
# Oceania : 192

# %%
unique_lable=visa_df['continent'].unique()
count=[]
for i in unique_lable:
    con2=visa_df['continent']==i
    count.append(len(visa_df[con2]))
    cols=['continent','count']
    continent_df=pd.DataFrame(zip(unique_lable,count),columns=cols)
continent_df.to_csv('continent_df.csv',index=False)

# %%
visa_df['continent'].value_counts()#gives total available unique lables
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
con_continent=visa_df['continent'].value_counts()
con_continent
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
countinent_vc=visa_df['continent'].value_counts()
countinent_vc
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
countinent_vc.keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
countinent_vc.values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
countinent_vc=visa_df['continent'].value_counts()
l1=countinent_vc.keys()
l2=countinent_vc.values
countinent_dc_df=pd.DataFrame(zip(l1,l2),columns=['Countinent','Count'])
countinent_dc_df
# Out:
#       Countinent  Count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
visa_df # Total data frame
visa_df['continent'] # specific column
visa_df['continent']=='Asia' # Specific lable
#####################################################
len(visa_df[visa_df['continent']=='Asia'])
len(visa_df[visa_df['continent']=='Africa'])
len(visa_df[visa_df['continent']=='Europe'])
len(visa_df[visa_df['continent']=='North America'])
len(visa_df[visa_df['continent']=='South America'])
len(visa_df[visa_df['continent']=='Oceania'])
########-------Method-1---------#########################
unique_labels= visa_df['continent'].unique()
count=[]
for i in unique_labels:
 con=visa_df['continent']==i # True and False
 count.append(len(visa_df[con]))
continent_df=pd.DataFrame(zip(unique_labels,count),
 columns=['Continent','Count'])
print(continent_df)
##################------ M-2----(Value counts)----##########################
continent_vc=visa_df['continent'].value_counts() # series
l1=continent_vc.keys()
l2=continent_vc.values
continent_vc_df=pd.DataFrame(zip(l1,l2),
columns=['continent','count'])
print(continent_vc_df)
# Out:
#        Continent  Count
# 0           Asia  16861
# 1         Africa    551
# 2  North America   3292
# 3         Europe   3732
# 4  South America    852
# 5        Oceania    192
#        continent  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
plt.figure(figsize=(10,6))
plt.bar('continent','count',data=continent_vc_df)
plt.xlabel("continent") # x-axis nam
# Out:
# Text(0.5, 0, 'continent')

# %%
#plt.bar(continent_df['cotinent','count',data=countinent_dc_df])
plt.figure(figsize=(10,6))
plt.bar('continent','count',data=continent_vc_df)
plt.xlabel("continent") # x-axis nam
plt.ylabel("count")
plt.title("Bar Chart")
plt.savefig("continent_Bar.jpg")
plt.show()

# %%
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
#countplot Example
plt.figure(figsize=(10,6))
l=visa_df['continent'].value_counts().keys()
sns.countplot(data=visa_df,x='continent',order=l)
plt.xlabel('continent')
plt.ylabel('count')
plt.title("Countplot")
plt.savefig('conticountPlot.jpg')
plt.show()
